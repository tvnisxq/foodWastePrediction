# %% [markdown]
# ## Food Wastage Prediction Project

# %% [markdown]
# ### Notebook for Data Analysis

# %%
# Import statement
import pandas as pd
df =pd.read_csv("E:\\food data set\\archive (1)\\food_wastage_data.csv")
df
# Out:
#      Type of Food  Number of Guests        Event Type  Quantity of Food  \
# 0            Meat               310         Corporate               450
# 1            Meat               400          Birthday               500
# 2      Vegetables               302          Birthday               371
# 3            Meat               491          Birthday               497
# 4            Meat               300         Corporate               400
# ...           ...               ...               ...               ...
# 1777  Baked Goods               310         Corporate               350
# 1778  Baked Goods               284  Social Gathering               443
# 1779       Fruits               220           Wedding               300
# 1780       Fruits               250           Wedding               350
# 1781  Baked Goods               400           Wedding               500
#
#      Storage Conditions Purchase History  Seasonality Preparation Method  \
# 0          Refrigerated          Regular  All Seasons             Buffet
# 1      Room Temperature          Regular       Winter             Buffet
# 2          Refrigerated          Regular       Summer             Buffet
# 3          Refrigerated          Regular  All Seasons        Finger Food
# 4          Refrigerated          Regular       Winter        Finger Food
# ...                 ...              ...          ...                ...
# 1777   Room Temperature          Regular       Summer        Finger Food
# 1778   Room Temperature          Regular       Winter             Buffet
# 1779   Room Temperature          Regular  All Seasons        Finger Food
# 1780   Room Temperature          Regular  All Seasons        Finger Food
# 1781   Room Temperature          Regular       Winter    Sit-down Dinner
#
#      Geographical Location   Pricing  Wastage Food Amount
# 0                    Urban       Low                   25
# 1                 Suburban      High                   40
# 2                 Suburban       Low                   27
# 3                    Rural      High                   32
# 4                    Urban  Moderate                   25
# ...                    ...       ...                  ...
# 1777                 Urban      High                   35
# 1778                 Rural       Low                   32
# 1779                 Urban  Moderate                   15
# 1780                 Rural  Moderate                   20
# 1781                 Rural      High                   45
#
# [1782 rows x 11 columns]

# %% [markdown]
# # Basic Inspections

# %%
df.head(10)  # view first ten rows.
# Out:
#   Type of Food  Number of Guests Event Type  Quantity of Food  \
# 0         Meat               310  Corporate               450
# 1         Meat               400   Birthday               500
# 2   Vegetables               302   Birthday               371
# 3         Meat               491   Birthday               497
# 4         Meat               300  Corporate               400
# 5         Meat               302   Birthday               371
# 6         Meat               240    Wedding               450
# 7         Meat               300    Wedding               400
# 8       Fruits               320  Corporate               400
# 9         Meat               400  Corporate               500
#
#   Storage Conditions Purchase History  Seasonality Preparation Method  \
# 0       Refrigerated          Regular  All Seasons             Buffet
# 1   Room Temperature          Regular       Winter             Buffet
# 2       Refrigerated          Regular       Summer             Buffet
# 3       Refrigerated          Regular  All Seasons        Finger Food
# 4       Refrigerated          Regular       Winter        Finger Food
# 5       Refrigerated          Regular       Summer             Buffet
# 6       Refrigerated          Regular       Winter    Sit-down Dinner
# 7       Refrigerated          Regular       Summer        Finger Food
# 8       Refrigerated          Regular  All Seasons             Buffet
# 9       Refrigerated       Occasional       Winter        Finger Food
#
#   Geographical Location   Pricing  Wastage Food Amount
# 0                 Urban       Low                   25
# 1              Suburban      High                   40
# 2              Suburban       Low                   27
# 3                 Rural      High                   32
# 4                 Urban  Moderate                   25
# 5              Suburban       Low                   27
# 6                 Urban       Low                   20
# 7                 Rural  Moderate                   25
# 8                 Urban      High                   45
# 9                 Urban      High                   40

# %%
df.tail(10)  # view last ten rows.
# Out:
#      Type of Food  Number of Guests        Event Type  Quantity of Food  \
# 1772       Fruits               429           Wedding               496
# 1773   Vegetables               350         Corporate               450
# 1774       Fruits               491          Birthday               497
# 1775         Meat               350          Birthday               450
# 1776         Meat               491  Social Gathering               497
# 1777  Baked Goods               310         Corporate               350
# 1778  Baked Goods               284  Social Gathering               443
# 1779       Fruits               220           Wedding               300
# 1780       Fruits               250           Wedding               350
# 1781  Baked Goods               400           Wedding               500
#
#      Storage Conditions Purchase History  Seasonality Preparation Method  \
# 1772   Room Temperature          Regular       Summer    Sit-down Dinner
# 1773       Refrigerated          Regular       Summer    Sit-down Dinner
# 1774   Room Temperature          Regular  All Seasons        Finger Food
# 1775   Room Temperature          Regular       Winter    Sit-down Dinner
# 1776   Room Temperature          Regular       Winter        Finger Food
# 1777   Room Temperature          Regular       Summer        Finger Food
# 1778   Room Temperature          Regular       Winter             Buffet
# 1779   Room Temperature          Regular  All Seasons        Finger Food
# 1780   Room Temperature          Regular  All Seasons        Finger Food
# 1781   Room Temperature          Regular       Winter    Sit-down Dinner
#
#      Geographical Location   Pricing  Wastage Food Amount
# 1772              Suburban       Low                   42
# 1773                 Urban      High                   35
# 1774                 Urban      High                   32
# 1775                 Urban  Moderate                   25
# 1776                 Urban      High                   32
# 1777                 Urban      High                   35
# 1778                 Rural       Low                   32
# 1779                 Urban  Moderate                   15
# 1780                 Rural  Moderate                   20
# 1781                 Rural      High                   45

# %%
df.shape   # Get number of rows and columns.
# Out:
# (1782, 11)

# %%
df.info()  # Check datatypes and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1782 entries, 0 to 1781
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Type of Food           1782 non-null   object
#  1   Number of Guests       1782 non-null   int64
#  2   Event Type             1782 non-null   object
#  3   Quantity of Food       1782 non-null   int64
#  4   Storage Conditions     1782 non-null   object
#  5   Purchase History       1782 non-null   object
#  6   Seasonality            1782 non-null   object
#  7   Preparation Method     1782 non-null   object
#  8   Geographical Location  1782 non-null   object
#  9   Pricing                1782 non-null   object
#  10  Wastage Food Amount    1782 non-null   int64
# dtypes: int64(3), object(8)
# memory usage: 153.3+ KB

# %%
df.describe()  # Get basic statistics
# Out:
#        Number of Guests  Quantity of Food  Wastage Food Amount
# count       1782.000000       1782.000000          1782.000000
# mean         317.804714        411.125701            28.536476
# std           67.829658         65.204674            10.461317
# min          207.000000        280.000000            10.000000
# 25%          267.000000        350.000000            20.000000
# 50%          302.000000        400.000000            26.500000
# 75%          350.000000        480.000000            35.000000
# max          491.000000        500.000000            63.000000

# %%
df.columns
# Out:
# Index(['Type of Food', 'Number of Guests', 'Event Type', 'Quantity of Food',
#        'Storage Conditions', 'Purchase History', 'Seasonality',
#        'Preparation Method', 'Geographical Location', 'Pricing',
#        'Wastage Food Amount'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum() # Check for missing values.
# Out:
# Type of Food             0
# Number of Guests         0
# Event Type               0
# Quantity of Food         0
# Storage Conditions       0
# Purchase History         0
# Seasonality              0
# Preparation Method       0
# Geographical Location    0
# Pricing                  0
# Wastage Food Amount      0
# dtype: int64

# %%
del df["Pricing"]
df
# Out:
#      Type of Food  Number of Guests        Event Type  Quantity of Food  \
# 0            Meat               310         Corporate               450
# 1            Meat               400          Birthday               500
# 2      Vegetables               302          Birthday               371
# 3            Meat               491          Birthday               497
# 4            Meat               300         Corporate               400
# ...           ...               ...               ...               ...
# 1777  Baked Goods               310         Corporate               350
# 1778  Baked Goods               284  Social Gathering               443
# 1779       Fruits               220           Wedding               300
# 1780       Fruits               250           Wedding               350
# 1781  Baked Goods               400           Wedding               500
#
#      Storage Conditions Purchase History  Seasonality Preparation Method  \
# 0          Refrigerated          Regular  All Seasons             Buffet
# 1      Room Temperature          Regular       Winter             Buffet
# 2          Refrigerated          Regular       Summer             Buffet
# 3          Refrigerated          Regular  All Seasons        Finger Food
# 4          Refrigerated          Regular       Winter        Finger Food
# ...                 ...              ...          ...                ...
# 1777   Room Temperature          Regular       Summer        Finger Food
# 1778   Room Temperature          Regular       Winter             Buffet
# 1779   Room Temperature          Regular  All Seasons        Finger Food
# 1780   Room Temperature          Regular  All Seasons        Finger Food
# 1781   Room Temperature          Regular       Winter    Sit-down Dinner
#
#      Geographical Location  Wastage Food Amount
# 0                    Urban                   25
# 1                 Suburban                   40
# 2                 Suburban                   27
# 3                    Rural                   32
# 4                    Urban                   25
# ...                    ...                  ...
# 1777                 Urban                   35
# 1778                 Rural                   32
# 1779                 Urban                   15
# 1780                 Rural                   20
# 1781                 Rural                   45
#
# [1782 rows x 10 columns]

# %%
df = df.drop_duplicates()  # Remove duplicate rows if any.
df
# Out:
#      Type of Food  Number of Guests        Event Type  Quantity of Food  \
# 0            Meat               310         Corporate               450
# 1            Meat               400          Birthday               500
# 2      Vegetables               302          Birthday               371
# 3            Meat               491          Birthday               497
# 4            Meat               300         Corporate               400
# ...           ...               ...               ...               ...
# 1776         Meat               491  Social Gathering               497
# 1777  Baked Goods               310         Corporate               350
# 1778  Baked Goods               284  Social Gathering               443
# 1779       Fruits               220           Wedding               300
# 1780       Fruits               250           Wedding               350
#
#      Storage Conditions Purchase History  Seasonality Preparation Method  \
# 0          Refrigerated          Regular  All Seasons             Buffet
# 1      Room Temperature          Regular       Winter             Buffet
# 2          Refrigerated          Regular       Summer             Buffet
# 3          Refrigerated          Regular  All Seasons        Finger Food
# 4          Refrigerated          Regular       Winter        Finger Food
# ...                 ...              ...          ...                ...
# 1776   Room Temperature          Regular       Winter        Finger Food
# 1777   Room Temperature          Regular       Summer        Finger Food
# 1778   Room Temperature          Regular       Winter             Buffet
# 1779   Room Temperature          Regular  All Seasons        Finger Food
# 1780   Room Temperature          Regular  All Seasons        Finger Food
#
#      Geographical Location  Wastage Food Amount
# 0                    Urban                   25
# 1                 Suburban                   40
# 2                 Suburban                   27
# 3                    Rural                   32
# 4                    Urban                   25
# ...                    ...                  ...
# 1776                 Urban                   32
# 1777                 Urban                   35
# 1778                 Rural                   32
# 1779                 Urban                   15
# 1780                 Rural                   20
#
# [1592 rows x 10 columns]

# %%
df = df.rename(columns={"Wastage Food Amount" : "Food Wasted(in Kgs)"})  # Rename columns.
df
# Out:
#      Type of Food  Number of Guests        Event Type  Quantity of Food  \
# 0            Meat               310         Corporate               450
# 1            Meat               400          Birthday               500
# 2      Vegetables               302          Birthday               371
# 3            Meat               491          Birthday               497
# 4            Meat               300         Corporate               400
# ...           ...               ...               ...               ...
# 1776         Meat               491  Social Gathering               497
# 1777  Baked Goods               310         Corporate               350
# 1778  Baked Goods               284  Social Gathering               443
# 1779       Fruits               220           Wedding               300
# 1780       Fruits               250           Wedding               350
#
#      Storage Conditions Purchase History  Seasonality Preparation Method  \
# 0          Refrigerated          Regular  All Seasons             Buffet
# 1      Room Temperature          Regular       Winter             Buffet
# 2          Refrigerated          Regular       Summer             Buffet
# 3          Refrigerated          Regular  All Seasons        Finger Food
# 4          Refrigerated          Regular       Winter        Finger Food
# ...                 ...              ...          ...                ...
# 1776   Room Temperature          Regular       Winter        Finger Food
# 1777   Room Temperature          Regular       Summer        Finger Food
# 1778   Room Temperature          Regular       Winter             Buffet
# 1779   Room Temperature          Regular  All Seasons        Finger Food
# 1780   Room Temperature          Regular  All Seasons        Finger Food
#
#      Geographical Location  Food Wasted(in Kgs)
# 0                    Urban                   25
# 1                 Suburban                   40
# 2                 Suburban                   27
# 3                    Rural                   32
# 4                    Urban                   25
# ...                    ...                  ...
# 1776                 Urban                   32
# 1777                 Urban                   35
# 1778                 Rural                   32
# 1779                 Urban                   15
# 1780                 Rural                   20
#
# [1592 rows x 10 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Understanding patterns and relationships in food wastage data

# %%
# Identify column types.
print (" Dataset overview:")
print (f" Total rows : {df.shape[0]}")
print (f" Total columns : {df.shape [1]}")
print("\n" + "=" * 60)

# Separate numerical and categorical columns.
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object','category']).columns.tolist()

print(f"\nNumerical Columns ({len(numerical_cols)}):")
for col in numerical_cols:
    print(f" - {col}")

print(f"\nCategorical columns ({len(categorical_cols)}):")
for col in categorical_cols:
    print(f" -{col}")
# Out:
#  Dataset overview:
#  Total rows : 1592
#  Total columns : 10
#
# ============================================================
#
# Numerical Columns (3):
#  - Number of Guests
#  - Quantity of Food
#  - Food Wasted(in Kgs)
#
# Categorical columns (7):
#  -Type of Food
#  -Event Type
#  -Storage Conditions
#  -Purchase History
#  -Seasonality
#  -Preparation Method
#  -Geographical Location

# %% [markdown]
# ## Visualize the target variable distribution:

# %%
# Histogram of food wastage
import matplotlib.pyplot as plt
import numpy as np 
plt.figure(figsize=(10,6))
# Create histogram
n, bins, patches = plt.hist(df['Food Wasted(in Kgs)'], bins=25, edgecolor='black')

plt.title('Distribution of Food Wastage', fontsize=14, fontweight='bold')

# 1. Add mean line (red)
plt.axvline(df['Food Wasted(in Kgs)'].mean(), color='red', linestyle='--', linewidth=2, label='Mean')

# 2. Add median line (blue)
plt.axvline(df['Food Wasted(in Kgs)'].median(), color='blue', linestyle='--', linewidth=2, label='Median')

# 3. Show legend
plt.legend()

# 4. Add grid
plt.grid(axis='y', alpha=0.3)

# 5 & 6. Add labels
plt.xlabel('Food Wasted (kg)', fontweight='bold')
plt.ylabel('Frequency', fontweight='bold')

# Color each bar based on height (tallest = darkest)
colors = plt.cm.viridis(np.linspace(0.3, 0.9, len(patches)))  # Beautiful gradient
for patch, color in zip(patches, colors):
    patch.set_facecolor(color)

plt.show()
